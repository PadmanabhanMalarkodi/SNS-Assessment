# %% [markdown]
# ## Problem Statement 4: Data Analysis
#
# ### Problem:
# #### Analyze a dataset and generate insights using a combination of descriptive statistics and visualizations.
# ### Requirements:
# #### Use Python libraries like Pandas, NumPy, and Matplotlib/Seaborn.
# #### Provide a Jupyter notebook with the analysis and visualizations.
# ### Evaluation Criteria:
# #### Accuracy and depth of the data analysis.
# #### Quality and clarity of the visualizations.
# #### Clean and well-documented code.

# %% [markdown]
# ### Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading the csv file

# %%
df1 = pd.read_csv('Bengaluru_House_Data.csv')
df1
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# ...

# %% [markdown]
# ### Displaying the shape

# %%
df1.shape
# Out:
# (13320, 9)

# %% [markdown]
# ### Removing duplicate records

# %%
df2 = df1.drop_duplicates()
df2.shape
# Out:
# (12791, 9)

# %% [markdown]
# ### Info
# #### The pandas info() function provides a concise summary of a DataFrame, including the number of non-null entries, data types of each column, and memory usage.

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12791 entries, 0 to 13318
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   area_type     12791 non-null  object
#  1   availability  12791 non-null  object
#  2   location      12790 non-null  object
#  3   size          12775 non-null  object
#  4   society       7463 non-null   object
#  5   total_sqft    12791 non-null  object
#  6   bath          12718 non-null  float64
#  7   balcony       12186 non-null  float64
#  8   price         12791 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 999.3+ KB

# %% [markdown]
# ### Describe
# #### The pandas describe() function provides a summary of statistics for numerical columns in a DataFrame, including measures like mean, standard deviation, min, max, and quartiles.

# %%
df2.describe()
# Out:
#                bath       balcony         price
# count  12718.000000  12186.000000  12791.000000
# mean       2.708602      1.582308    114.317646
# std        1.357764      0.822536    151.480310
# min        1.000000      0.000000      8.000000
# 25%        2.000000      1.000000     50.000000
# 50%        2.000000      2.000000     73.000000
# 75%        3.000000      2.000000    121.000000
# max       40.000000      3.000000   3600.000000

# %%
df2.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df2['total_sqft'].dtype
# Out:
# dtype('O')

# %%
df2.iloc[50:60]
# Out:
#                area_type   availability                location       size  \
# 50  Super built-up  Area  Ready To Move            Adarsh Nagar      2 BHK
# 51  Super built-up  Area         18-Mar             Bhoganhalli      3 BHK
# 52        Built-up  Area  Ready To Move              Whitefield      3 BHK
# 53  Super built-up  Area  Ready To Move    Lakshminarayana Pura      2 BHK
# 54  Super built-up  Area  Ready To Move               Yelahanka      3 BHK
# 55  Super built-up  Area  Ready To Move              Begur Road      2 BHK
# 56        Built-up  Area         20-Feb             Devanahalli  4 Bedroom
# 57  Super built-up  Area  Ready To Move   Ramakrishnappa Layout      2 BHK
# 58            Plot  Area  Ready To Move           Murugeshpalya  6 Bedroom
# 59  Super built-up  Area  Ready To Move  Govindaraja Nagar Ward      2 BHK
#
#     society   total_sqft  bath  balcony  price
# 50  Bhncyis         1270   2.0      1.0   50.0
# 51  Rosha I         1670   3.0      1.0   99.0
# ...

# %%
# If it is a range we can take the average
# If the unit is in meter or perch or any other we are ignoring it.

def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0])+float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
df3 = df2.copy()
df3['total_sqft'] = df3['total_sqft'].apply(convert_sqft_to_num)
df3
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society  total_sqft  bath  balcony   price
# 0          2 BHK  Coomee       1056.0   2.0      1.0   39.07
# ...

# %%
df3['total_sqft'].dtype
# Out:
# dtype('float64')

# %%
df3.describe()
# Out:
#         total_sqft          bath       balcony         price
# count  12745.00000  12718.000000  12186.000000  12791.000000
# mean    1569.60368      2.708602      1.582308    114.317646
# std     1259.83493      1.357764      0.822536    151.480310
# min        1.00000      1.000000      0.000000      8.000000
# 25%     1100.00000      2.000000      1.000000     50.000000
# 50%     1280.00000      2.000000      2.000000     73.000000
# 75%     1691.00000      3.000000      2.000000    121.000000
# max    52272.00000     40.000000      3.000000   3600.000000

# %% [markdown]
# ### Handling Null values

# %%
df3.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5328
# total_sqft        46
# bath              73
# balcony          605
# price              0
# dtype: int64

# %% [markdown]
# ### i) Non-numerical column
# #### There so many null values in society column, Inorder to prevent the loss of data I'm removing that column for my analysis.

# %%
df4 = df3.drop(['society'], axis = 1)
df4.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    total_sqft  bath  balcony   price
# 0      1056.0   2.0      1.0   39.07
# 1      2600.0   5.0      3.0  120.00
# 2      1440.0   2.0      3.0   62.00
# 3      1521.0   3.0      1.0   95.00
# 4      1200.0   2.0      1.0   51.00

# %%
df4.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          1
# size             16
# total_sqft       46
# bath             73
# balcony         605
# price             0
# dtype: int64

# %%
df4 = df4.dropna(subset=['location'], axis=0)  # Drops rows where 'location' is null
df4.isnull().sum()
# Out:
# area_type         0
# availability      0
# location          0
# size             16
# total_sqft       46
# bath             73
# balcony         605
# price             0
# dtype: int64

# %% [markdown]
# ### ii) Numerical columns

# %%
# Dropping rows where 'size' is null
df4 = df4.dropna(subset=['size'], axis=0)

# Replacing missing values in 'bath' column with the mode
df4['bath'] = df4['bath'].fillna(df4['bath'].mode()[0])

# Replacing missing values in 'total_sqft' column with the mean
df4['total_sqft'] = df4['total_sqft'].fillna(df4['total_sqft'].mean())

# Replacing missing values in 'balcony' column with the mean
df4['balcony'] = df4['balcony'].fillna(df4['balcony'].mean())

# Checking for remaining missing values
print(df4.isnull().sum())
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df4.shape
# Out:
# (12774, 8)

# %%
df5 = df4.copy()

df5['bhk'] = df5['size'].apply(lambda x: int(x.split(' ')[0]))
df5
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  total_sqft  bath   balcony   price  bhk
# 0          2 BHK      1056.0   2.0  1.000000   39.07    2
# ...

# %% [markdown]
# ## Exploratory Analysis Analysis (EDA)

# %%
df6 = df5.drop(['area_type', 'availability', 'size'], axis = 1)
df6
# Out:
#                        location  total_sqft  bath   balcony   price  bhk
# 0      Electronic City Phase II      1056.0   2.0  1.000000   39.07    2
# 1              Chikka Tirupathi      2600.0   5.0  3.000000  120.00    4
# 2                   Uttarahalli      1440.0   2.0  3.000000   62.00    3
# 3            Lingadheeranahalli      1521.0   3.0  1.000000   95.00    3
# 4                      Kothanur      1200.0   2.0  1.000000   51.00    2
# ...                         ...         ...   ...       ...     ...  ...
# 13314         Green Glen Layout      1715.0   3.0  3.000000  112.00    3
# 13315                Whitefield      3453.0   4.0  0.000000  231.00    5
# 13316             Richards Town      3600.0   5.0  1.582273  400.00    4
# 13317     Raja Rajeshwari Nagar      1141.0   2.0  1.000000   60.00    2
# 13318           Padmanabhanagar      4689.0   4.0  1.000000  488.00    4
#
# [12774 rows x 6 columns]

# %%
# Aggregating prices by bhk
df6_grouped = df6.groupby('bhk')['price'].mean().reset_index()

# Creating a bar plot
plt.bar(df6_grouped['bhk'], df6_grouped['price'])

# Adding labels
plt.xlabel('Number of Bedrooms (BHK)')
plt.ylabel('Average Price')

# Displaying the plot
plt.show()

# %% [markdown]
# ## Outlier detection using box plot

# %%
# Box plot for a numerical column

plt.boxplot(x=df6['bath'])
plt.title('Outlier Detection for bathroom')
plt.xlabel('Value')
plt.show()

# %% [markdown]
# ## Outlier removal using IQR method

# %%
# Step 1: Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = df6['bath'].quantile(0.25)
Q3 = df6['bath'].quantile(0.75)

# Step 2: Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Step 3: Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 4: Filter the DataFrame to remove outliers
df6 = df6[(df6['bath'] >= lower_bound) & (df6['bath'] <= upper_bound)]

# Step 5: Plot the boxplot again to confirm outliers are removed
plt.boxplot(x=df6_no_outliers['bath'])
plt.title('Outlier Detection for Bathroom (After Removal)')
plt.xlabel('Value')
plt.show()

# %%
df6.shape
# Out:
# (11742, 6)

# %%
import matplotlib.pyplot as plt

# Define the columns you want to analyze
columns_to_plot = ['total_sqft', 'bhk', 'price', 'balcony']

# Create a single row of subplots with 4 columns
fig, axes = plt.subplots(1, 4, figsize=(20, 6))

# Iterate over the columns and create a boxplot for each
for i, col in enumerate(columns_to_plot):
    axes[i].boxplot(df6[col].dropna())  # Drop NaN values for plotting
    axes[i].set_title(f'Outlier Detection for {col}')
    axes[i].set_xlabel(col)

# Adjust the layout
plt.tight_layout()

# Display the plots
plt.show()

# %%
plt.hist(df6['bhk'])
plt.show()

# %% [markdown]
# ### Pair Plot

# %%
# Pair plot for numerical features
sns.pairplot(df6[['total_sqft', 'bhk', 'price']])
plt.show()
# Out:
# C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ## Correlation matrix

# %%
# Compute correlation matrix

df7 = df6.drop(['location'], axis = 1)
correlation_matrix = df7.corr()

# Heatmap for correlation matrix
sns.heatmap(correlation_matrix)
plt.title('Correlation Matrix')
plt.show()
